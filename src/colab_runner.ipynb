# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ------------------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.12.0
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.4
# Babel                         2.10.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# ...

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !nvidia-smi
# Out:
# Wed May 18 16:23:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Sony_pm25-master/src/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Sony_pm25-master/src

# %%
# !ls
# Out:
# colab_runner.ipynb	   __pycache__		   SAINT_utils.py
# EDA.ipynb		   runner.py		   SAINT_wrap.py
# EDA_pre.ipynb		   SAINT_augmentations.py  TabNet_Learning.py
# LightGBM_Learning.py	   SAINT_Learning.py	   TabNet_optuna.py
# LightGBM_optuna.py	   SAINT_models		   TabNet_Predicting.py
# LightGBM_Predicting.py	   SAINT_optuna.py	   TabNet_Preprocessing.py
# LightGBM_Preprocessing.py  SAINT_Predicting.py	   TabNet.py
# LightGBM.py		   SAINT_Preprocessing.py  test.ipynb

# %%
"""# SAINT learning test
# !pip install torch==1.8.1 torchvision==0.9.1 torchaudio==0.8.1
# !pip install wandb einops openml
# !python SAINT_Learning.py"""
# Out:
# '# SAINT learning test\n!pip install torch==1.8.1 torchvision==0.9.1 torchaudio==0.8.1\n!pip install wandb einops openml\n!python SAINT_Learning.py'

# %%
# run tabnet and lightGBM
# !pip install pytorch-tabnet==3.1.1
# !pip install einops
# !python3 runner.py
# Out:
# ...
#
# [CHECK POINT]: Run dir >>  ../results/20220518-162447
#
#
# [CHECK POINT]: START "get_train_data"
#
# shape of train data:  (195941, 54)
# categories:  ['Country']
#
# [CHECK POINT]: END "get_train_data"
#
#
# [CHECK POINT]: START "get_test_data"
#
# shape of test data:  (53509, 52)
#
# [CHECK POINT]: END "get_test_data"
#
# Device used : cuda
#
# [CHECK POINT]: START "pretrain tabnet."
#
# GPU RAM Usage: .................... 2/16280 MiB (0.0%)
# epoch 0  | loss: 10540.86005| val_0_unsup_loss: 7122.38525|  0:00:52s
# Stop training because you reached max_epochs = 1 with best_epoch = 0 and best_val_0_unsup_loss = 7122.38525
# Best weights from best epoch are automatically used!
#
# [CHECK POINT]: END "pretrain tabnet." train_time=63.24359583854675
#
# GPU RAM Usage: ||||||||||||||...... 11925/16280 MiB (73.2%)
#
# [CHECK POINT]: START  1 "fold"
#
# train city:  ['Darwin' 'Melbourne' 'Newcastle' 'Perth' 'Antwerpen' 'Charleroi'
# ...

# %%
# !pip install pytorch-tabnet==3.1.1
# !pip install optuna
# !python3 TabNet_optuna.py

# %%
# !python3 LightGBM_optuna.py

# %%
# !nvidia-smi
# Out:
# Wed May 18 16:43:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install pytorch-tabnet==3.1.1
# !python3 TabNet_Predicting.py
# Out:
# ...
#
# [CHECK POINT]: Run dir >>  ../results/20220518-164407
#
#
# [CHECK POINT]: START "get_train_data"
#
# shape of train data:  (195941, 54)
# categories:  ['Country']
#
# [CHECK POINT]: END "get_train_data"
#
#
# [CHECK POINT]: START "get_test_data"
#
# shape of test data:  (53509, 52)
#
# [CHECK POINT]: END "get_test_data"
#
# Device used : cuda
#
# [CHECK POINT]: START "pretrain tabnet."
#
# GPU RAM Usage: .................... 2/16280 MiB (0.0%)
# epoch 0  | loss: 10540.86005| val_0_unsup_loss: 7122.38525|  0:00:52s
# Stop training because you reached max_epochs = 1 with best_epoch = 0 and best_val_0_unsup_loss = 7122.38525
# Best weights from best epoch are automatically used!
#
# [CHECK POINT]: END "pretrain tabnet." train_time=56.02885437011719
#
# GPU RAM Usage: ||||||||||||||...... 11925/16280 MiB (73.2%)
#
# [CHECK POINT]: START  1 "fold"
#
# train city:  ['Darwin' 'Melbourne' 'Newcastle' 'Perth' 'Antwerpen' 'Charleroi'
# ...
